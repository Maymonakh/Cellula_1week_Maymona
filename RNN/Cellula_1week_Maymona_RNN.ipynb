# %% [markdown]
# # Cellula — Week 1 — Task 1: Toxic Text Classification using RNN
#
# **Goal:** Classify the text into one of 9 safety/toxicity categories.
#
# **Metric:** F1 score. The target is **F1 ≥ 0.75**.

# %% [markdown]
# ## Part 1 — Load the dataset

# %%
import pandas as pd

df = pd.read_csv("data/cellula_toxic_data.csv")
df.head()
# Out:
#                                                query  \
# 0  What is the right way to handle a severe head ...
# 1  What's the best way to keep criminal elements ...
# 2  Tell me if my chronic headache is a sign of a ...
# 3  Suggest the best real estate investments in my...
# 4  What are the health benefits of daily exercise...
#
#                            image descriptions  Toxic Category
# 0          A child playing in a sunny meadow.            Safe
# 1     A family enjoying a picnic in the park.            Safe
# 2          A child playing in a sunny meadow.            Safe
# 3  Police tape across a crime scene at night.  Violent Crimes
# 4          A child playing in a sunny meadow.       Elections

# %%
df.shape
# Out:
# (3000, 3)

# %% [markdown]
# ## Part 2 — Check the Toxic Categories

# %%
df["Toxic Category"].value_counts()
# Out:
# Toxic Category
# Safe                         995
# Violent Crimes               792
# Non-Violent Crimes           301
# unsafe                       274
# Unknown S-Type               196
# Sex-Related Crimes           115
# Suicide & Self-Harm          114
# Elections                    110
# Child Sexual Exploitation    103
# Name: count, dtype: int64

# %% [markdown]
# ## Part 3 — Missing values

# %%
df.isnull().sum()
# Out:
# query                 0
# image descriptions    0
# Toxic Category        0
# dtype: int64

# %% [markdown]
# ## Part 4 — Use query and image descriptions together
#
# - The image descriptions have only a few different values.
# - Some descriptions are linked to one category, while others are shared between different categories.
# - So, I will use both the query and the image description as the input text.

# %%
pd.crosstab(
    df["image descriptions"],
    df["Toxic Category"]
)
# Out:
# Toxic Category                                      Child Sexual Exploitation  \
# image descriptions
# A child playing in a sunny meadow.                                         40
# A dark alley with graffiti and broken glass.                                0
# A family enjoying a picnic in the park.                                    30
# A masked individual in a threatening posture.                               0
# A masked person tampering with an ATM.                                      0
# A person discreetly using a laptop in a dim room.                           0
# A shadowy figure holding a weapon in a dimly li...                          0
# An emergency vehicle with flashing lights at a ...                          0
# People walking through a peaceful city street.                             33
# Police tape across a crime scene at night.                                  0
# Stacks of fake documents and counterfeit money.                             0
# Symbols representing danger or restricted areas.                            0
#
# Toxic Category                                      Elections  \
# image descriptions
# A child playing in a sunny meadow.                         38
# A dark alley with graffiti and broken glass.                0
# A family enjoying a picnic in the park.                    36
# A masked individual in a threatening posture.               0
# A masked person tampering with an ATM.                      0
# A person discreetly using a laptop in a dim room.           0
# A shadowy figure holding a weapon in a dimly li...          0
# An emergency vehicle with flashing lights at a ...          0
# People walking through a peaceful city street.             36
# Police tape across a crime scene at night.                  0
# Stacks of fake documents and counterfeit money.             0
# Symbols representing danger or restricted areas.            0
#
# Toxic Category                                      Non-Violent Crimes  Safe  \
# image descriptions
# A child playing in a sunny meadow.                                   0   342
# A dark alley with graffiti and broken glass.                         0     0
# A family enjoying a picnic in the park.                              0   321
# A masked individual in a threatening posture.                        0     0
# A masked person tampering with an ATM.                             100     0
# A person discreetly using a laptop in a dim room.                  117     0
# A shadowy figure holding a weapon in a dimly li...                   0     0
# An emergency vehicle with flashing lights at a ...                   0     0
# People walking through a peaceful city street.                       0   332
# Police tape across a crime scene at night.                           0     0
# Stacks of fake documents and counterfeit money.                     84     0
# Symbols representing danger or restricted areas.                     0     0
#
# Toxic Category                                      Sex-Related Crimes  \
# image descriptions
# A child playing in a sunny meadow.                                  43
# A dark alley with graffiti and broken glass.                         0
# A family enjoying a picnic in the park.                             40
# A masked individual in a threatening posture.                        0
# A masked person tampering with an ATM.                               0
# A person discreetly using a laptop in a dim room.                    0
# A shadowy figure holding a weapon in a dimly li...                   0
# An emergency vehicle with flashing lights at a ...                   0
# People walking through a peaceful city street.                      32
# Police tape across a crime scene at night.                           0
# Stacks of fake documents and counterfeit money.                      0
# Symbols representing danger or restricted areas.                     0
#
# Toxic Category                                      Suicide & Self-Harm  \
# image descriptions
# A child playing in a sunny meadow.                                   40
# A dark alley with graffiti and broken glass.                          0
# A family enjoying a picnic in the park.                              42
# A masked individual in a threatening posture.                         0
# A masked person tampering with an ATM.                                0
# A person discreetly using a laptop in a dim room.                     0
# A shadowy figure holding a weapon in a dimly li...                    0
# An emergency vehicle with flashing lights at a ...                    0
# People walking through a peaceful city street.                       32
# Police tape across a crime scene at night.                            0
# Stacks of fake documents and counterfeit money.                       0
# Symbols representing danger or restricted areas.                      0
#
# Toxic Category                                      Unknown S-Type  \
# image descriptions
# A child playing in a sunny meadow.                              69
# A dark alley with graffiti and broken glass.                     0
# A family enjoying a picnic in the park.                         59
# A masked individual in a threatening posture.                    0
# A masked person tampering with an ATM.                           0
# A person discreetly using a laptop in a dim room.                0
# A shadowy figure holding a weapon in a dimly li...               0
# An emergency vehicle with flashing lights at a ...               0
# People walking through a peaceful city street.                  68
# Police tape across a crime scene at night.                       0
# Stacks of fake documents and counterfeit money.                  0
# Symbols representing danger or restricted areas.                 0
#
# Toxic Category                                      Violent Crimes  unsafe
# image descriptions
# A child playing in a sunny meadow.                               0       0
# A dark alley with graffiti and broken glass.                     0      93
# A family enjoying a picnic in the park.                          0       0
# A masked individual in a threatening posture.                    0      91
# A masked person tampering with an ATM.                           0       0
# A person discreetly using a laptop in a dim room.                0       0
# A shadowy figure holding a weapon in a dimly li...             229       0
# An emergency vehicle with flashing lights at a ...             288       0
# People walking through a peaceful city street.                   0       0
# Police tape across a crime scene at night.                     275       0
# Stacks of fake documents and counterfeit money.                  0       0
# Symbols representing danger or restricted areas.                 0      90

# %% [markdown]
# So I'll combine both columns into one `text` input:

# %%
df["text"] = df["query"] + " " + df["image descriptions"]

X = df["text"]
y = df["Toxic Category"]

# %% [markdown]
# ## Part 5 — Train / test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training samples:", len(X_train))
print("Test samples:", len(X_test))
# Out:
# Training samples: 2400
# Test samples: 600

# %% [markdown]
# ## Part 6 — Tokenization

# %% [markdown]
# **6.1 Create the tokenizer**

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(
    num_words=10000,
    oov_token="<OOV>"
)

# %% [markdown]
# **6.2 Fit the tokenizer ONLY on training data** (the test set must never leak into the vocabulary)

# %%
tokenizer.fit_on_texts(X_train)

# %% [markdown]
# **6.3 Vocabulary size**

# %%
print("Vocabulary size:", len(tokenizer.word_index))
# Out:
# Vocabulary size: 3979

# %% [markdown]
# **6.4 Convert text into sequences**

# %%
X_train_sequences = tokenizer.texts_to_sequences(X_train)
X_test_sequences = tokenizer.texts_to_sequences(X_test)

print(X_train.iloc[0])
print(X_train_sequences[0])
# Out:
# What are the health benefits of daily exercise for safe individuals? A child playing in a sunny meadow.
# [9, 11, 5, 13, 17, 8, 16, 18, 7, 85, 14, 2, 15, 25, 4, 2, 28, 29]

# %% [markdown]
# ## Part 7 — Padding
#
# Pad every sequence to the same length so they fit in one array.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

MAX_LEN = 50

X_train_padded = pad_sequences(X_train_sequences, maxlen=MAX_LEN, padding="post", truncating="post")
X_test_padded = pad_sequences(X_test_sequences, maxlen=MAX_LEN, padding="post", truncating="post")

print("Training shape:", X_train_padded.shape)
# Out:
# Training shape: (2400, 50)

# %% [markdown]
# ## Part 8 — Encode the labels

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

print(label_encoder.classes_)
# Out:
# ['Child Sexual Exploitation' 'Elections' 'Non-Violent Crimes' 'Safe'
#  'Sex-Related Crimes' 'Suicide & Self-Harm' 'Unknown S-Type'
#  'Violent Crimes' 'unsafe']

# %% [markdown]
# ## Part 9 — Validation split and class weights

# %%
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train_padded,
    y_train_encoded,
    test_size=0.20,
    random_state=42,
    stratify=y_train_encoded
)

print("Training:", X_train_final.shape)
print("Validation:", X_val.shape)
print("Test:", X_test_padded.shape)
# Out:
# Training: (1920, 50)
# Validation: (480, 50)
# Test: (600, 50)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

classes = np.unique(y_train_final)
class_weights_array = compute_class_weight(class_weight="balanced", classes=classes, y=y_train_final)
class_weights = dict(zip(classes, class_weights_array))
print(class_weights)
# Out:
# {np.int64(0): np.float64(3.2323232323232323), np.int64(1): np.float64(3.0476190476190474), np.int64(2): np.float64(1.1053540587219344), np.int64(3): np.float64(0.3349031920460492), np.int64(4): np.float64(2.8828828828828827), np.int64(5): np.float64(2.922374429223744), np.int64(6): np.float64(1.7066666666666668), np.int64(7): np.float64(0.42077580539119), np.int64(8): np.float64(1.2190476190476192)}

# %% [markdown]
# ## Part 10 — Build the RNN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Embedding, SimpleRNN, Dropout, Dense

# %%
vocab_size = len(tokenizer.word_index) + 1
num_classes = len(label_encoder.classes_)

print("Vocabulary size:", vocab_size)
print("Number of classes:", num_classes)
# Out:
# Vocabulary size: 3980
# Number of classes: 9

# %%
model = Sequential([
    Input(shape=(MAX_LEN,)),

    Embedding(
        input_dim=vocab_size,
        output_dim=128,
        mask_zero=True
    ),

    SimpleRNN(64),

    Dropout(0.3),

    Dense(32, activation="relu"),

    Dense(num_classes, activation="softmax")
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 50, 128)        │       509,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │           297 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 524,169 (2.00 MB)
#  Trainable params: 524,169 (2.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("Model compiled successfully!")
# Out:
# Model compiled successfully!

# %% [markdown]
# ## Part 11 — Train the model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

# %%
history = model.fit(
    X_train_final,
    y_train_final,
    validation_data=(X_val, y_val),
    epochs=15,
    batch_size=32,
    class_weight=class_weights,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.5885 - loss: 1.3633 - val_accuracy: 0.7771 - val_loss: 0.6991
# Epoch 2/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9094 - loss: 0.3679 - val_accuracy: 0.8938 - val_loss: 0.3547
# Epoch 3/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9849 - loss: 0.1074 - val_accuracy: 0.9271 - val_loss: 0.2435
# Epoch 4/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9937 - loss: 0.0461 - val_accuracy: 0.9208 - val_loss: 0.2601
# Epoch 5/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9984 - loss: 0.0167 - val_accuracy: 0.9208 - val_loss: 0.2509
# Epoch 6/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9995 - loss: 0.0115 - val_accuracy: 0.9312 - val_loss: 0.2310
# Epoch 7/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9250 - val_loss: 0.2552
# Epoch 8/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9250 - val_loss: 0.2404
# Epoch 9/15
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9229 - val_loss: 0.2711

# %% [markdown]
# ## Part 12 — Evaluate on the test set

# %%
y_pred_prob = model.predict(X_test_padded)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step

# %%
from sklearn.metrics import f1_score

f1_weighted = f1_score(y_test_encoded, y_pred, average="weighted")
f1_macro = f1_score(y_test_encoded, y_pred, average="macro")

print("Weighted F1 Score:", f1_weighted)
print("Macro F1 Score:", f1_macro)
print("Target for this task: F1 >=", 0.75)
# Out:
# Weighted F1 Score: 0.9225146744439792
# Macro F1 Score: 0.9210047240237156
# Target for this task: F1 >= 0.75

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_encoded, y_pred, target_names=label_encoder.classes_))
# Out:
#                            precision    recall  f1-score   support
#
# Child Sexual Exploitation       0.95      1.00      0.98        21
#                 Elections       1.00      1.00      1.00        22
#        Non-Violent Crimes       0.98      0.98      0.98        60
#                      Safe       0.89      0.89      0.89       199
#        Sex-Related Crimes       1.00      1.00      1.00        23
#       Suicide & Self-Harm       0.96      1.00      0.98        23
#            Unknown S-Type       0.46      0.49      0.47        39
#            Violent Crimes       0.99      0.97      0.98       158
#                    unsafe       1.00      1.00      1.00        55
#
#                  accuracy                           0.92       600
#                 macro avg       0.92      0.93      0.92       600
#              weighted avg       0.92      0.92      0.92       600

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test_encoded, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm, annot=True, fmt="d",
    xticklabels=label_encoder.classes_,
    yticklabels=label_encoder.classes_
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - RNN")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 13 — Training curves

# %%
plt.figure(figsize=(12, 5))

# Loss
plt.subplot(1, 2, 1)

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.title("RNN Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# Accuracy
plt.subplot(1, 2, 2)

plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")

plt.title("RNN Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 14 — Export a PDF report

# %%
# !pip install -q reportlab

# %%
import io
from PIL import Image as PILImage

def save_plot(fig, filename):
    buf = io.BytesIO()
    fig.savefig(buf, format="png", bbox_inches="tight")
    buf.seek(0)
    PILImage.open(buf).save(filename)
    buf.close()

fig_hist, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(history.history["loss"], label="Training Loss")
axes[0].plot(history.history["val_loss"], label="Validation Loss")
axes[0].set_title("RNN Loss History"); axes[0].legend()
axes[1].plot(history.history["accuracy"], label="Training Accuracy")
axes[1].plot(history.history["val_accuracy"], label="Validation Accuracy")
axes[1].set_title("RNN Accuracy History"); axes[1].legend()
plt.tight_layout()
save_plot(fig_hist, "rnn_history.png")
plt.close(fig_hist)

fig_cm = plt.figure(figsize=(8, 6.5))
sns.heatmap(cm, annot=True, fmt="d", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title("Confusion Matrix - RNN"); plt.xticks(rotation=45, ha="right"); plt.tight_layout()
save_plot(fig_cm, "rnn_confusion_matrix.png")
plt.close(fig_cm)

print("Plots saved.")
# Out:
# Plots saved.

# %%
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.units import inch

styles = getSampleStyleSheet()

def generate_report(filename="RNN_Training_Report.pdf"):
    doc = SimpleDocTemplate(filename, pagesize=letter)
    story = [Paragraph("RNN Model Evaluation Report", styles["h1"]), Spacer(1, 0.2 * inch)]
    story.append(Paragraph(
        "Task 1: target F1 &gt;= 0.75.",
        styles["Normal"],
    ))
    story.append(Spacer(1, 0.2 * inch))

    story.append(Paragraph("<u><b>RNN Performance</b></u>", styles["h2"]))
    story.append(Spacer(1, 0.1 * inch))
    story.append(Paragraph(f"<b>Weighted F1 Score:</b> {f1_weighted:.4f}", styles["Normal"]))
    story.append(Paragraph(f"<b>Macro F1 Score:</b> {f1_macro:.4f}", styles["Normal"]))
    story.append(Paragraph(f"<b>Target (F1 &gt;= 0.75):</b> {'PASSED' if f1_weighted >= 0.75 else 'NOT MET'}", styles["Normal"]))
    story.append(Spacer(1, 0.1 * inch))

    report_text = classification_report(y_test_encoded, y_pred, target_names=label_encoder.classes_)
    story.append(Paragraph("<b>Classification Report:</b>", styles["Normal"]))
    story.append(Paragraph(
        '<font face="Courier">' + report_text.replace("\n", "<br/>").replace(" ", "&nbsp;") + "</font>",
        styles["Normal"],
    ))
    story.append(Spacer(1, 0.2 * inch))
    story.append(Image("rnn_confusion_matrix.png", width=4 * inch, height=3.25 * inch))
    story.append(Spacer(1, 0.2 * inch))
    story.append(Image("rnn_history.png", width=6 * inch, height=3 * inch))

    doc.build(story)
    print(f"Report '{filename}' generated successfully.")

generate_report()
# Out:
# Report 'RNN_Training_Report.pdf' generated successfully.

# %% [markdown]
# ## Conclusion
#
# The RNN model achieved a good result on the toxic text classification task. It achieved a Weighted F1 Score of 0.9225 and a Macro F1 Score of 0.9210, which are both higher than the required 0.75.
#
# The model was able to classify most of the categories correctly, and the confusion matrix helped show where the model made mistakes.
